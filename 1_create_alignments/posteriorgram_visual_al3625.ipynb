# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
pfile = open("/home/lankaraniamir/new/kaldi-trunk/egs/new/ASA_ICASSP2021/a2l/results/dev/ANiMAL_-_Rockshow/phone_post.npy", "rb")

pgrams = np.load(pfile)
pgrams = pgrams.transpose()
print(pgrams.shape)
pgrams = np.flipud(pgrams)
plt.title("Posteriorgram")
plt.xlabel("Time (s)")
plt.ylabel("Phoneme Number")
plt.imshow(pgrams, cmap='Greys', interpolation='nearest', aspect="auto", extent=(0, 135, 0, 40))
plt.rcParams['figure.figsize'] = [14*.9, 10*.8]
# print(pgrams.shape)
# Out:
# (41, 164)
